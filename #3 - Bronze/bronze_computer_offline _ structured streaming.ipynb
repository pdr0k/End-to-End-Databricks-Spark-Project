# %%
from pyspark.sql.functions import *  #core pyspark sql funcions for data transformation
from pyspark.sql.streaming import *  #structured streaming

# %%
#from pyspark.sql import SparkSession

#creating a SparkSession's instance
#spark = SparkSession.builder \
    #.appName("NameofStreaming") \
    #.getOrCreate()

# %%
#listing storage

dbutils.fs.ls("dbfs:/FileStore/landing_zone/Computer/Offline/Computer/")
# Out:
# [FileInfo(path='dbfs:/FileStore/landing_zone/Computer/Offline/Computer/Computer_2024-12-23 19:37:35.933693.parquet', name='Computer_2024-12-23 19:37:35.933693.parquet', size=7552, modificationTime=1734982657000),
#  FileInfo(path='dbfs:/FileStore/landing_zone/Computer/Offline/Computer/Computer_2024-12-23 19:37:47.358983.parquet', name='Computer_2024-12-23 19:37:47.358983.parquet', size=7477, modificationTime=1734982668000),
#  FileInfo(path='dbfs:/FileStore/landing_zone/Computer/Offline/Computer/Computer_2024-12-23 19:37:58.704002.parquet', name='Computer_2024-12-23 19:37:58.704002.parquet', size=7441, modificationTime=1734982679000),
#  FileInfo(path='dbfs:/FileStore/landing_zone/Computer/Offline/Computer/Computer_2024-12-23 19:38:09.982125.parquet', name='Computer_2024-12-23 19:38:09.982125.parquet', size=7442, modificationTime=1734982691000),
#  FileInfo(path='dbfs:/FileStore/landing_zone/Computer/Offline/Computer/Computer_2024-12-23 19:38:21.211050.parquet', name='Computer_2024-12-23 19:38:21.211050.parquet', size=7664, modificationTime=1734982702000),
#  FileInfo(path='dbfs:/FileStore/landing_zone/Computer/Offline/Computer/Computer_2024-12-23 19:38:32.454861.parquet', name='Computer_2024-12-23 19:38:32.454861.parquet', size=7535, modificationTime=1734982713000),
#  FileInfo(path='dbfs:/FileStore/landing_zone/Computer/Offline/Computer/Computer_2024-12-23 19:38:43.701532.parquet', name='Computer_2024-12-23 19:38:43.701532.parquet', size=7534, modificationTime=1734982724000),
#  FileInfo(path='dbfs:/FileStore/landing_zone/Computer/Offline/Computer/Computer_2024-12-23 19:38:54.932556.parquet', name='Computer_2024-12-23 19:38:54.932556.parquet', size=7542, modificationTime=1734982736000),
#  FileInfo(path='dbfs:/FileStore/landing_zone/Computer/Offline/Computer/Computer_2024-12-23 19:39:06.159151.parquet', name='Computer_2024-12-23 19:39:06.159151.parquet', size=7369, modificationTime=1734982747000),
#  FileInfo(path='dbfs:/FileStore/landing_zone/Computer/Offline/Computer/Computer_2024-12-23 19:39:17.673948.parquet', name='Computer_2024-12-23 19:39:17.673948.parquet', size=7478, modificationTime=1734982758000),
#  FileInfo(path='dbfs:/FileStore/landing_zone/Computer/Offline/Computer/Computer_2024-12-23 19:39:28.886109.parquet', name='Computer_2024-12-23 19:39:28.886109.parquet', size=7545, modificationTime=1734982770000),
#  FileInfo(path='dbfs:/FileStore/landing_zone/Computer/Offline/Computer/Computer_2024-12-23 19:40:40.829600.parquet', name='Computer_2024-12-23 19:40:40.829600.parquet', size=7428, modificationTime=1734982842000),
#  FileInfo(path='dbfs:/FileStore/landing_zone/Computer/Offline/Computer/Computer_2024-12-23 19:40:52.266770.parquet', name='Computer_2024-12-23 19:40:52.266770.parquet', size=7454, modificationTime=1734982853000),
#  FileInfo(path='dbfs:/FileStore/landing_zone/Computer/Offline/Computer/Computer_2024-12-23 19:41:03.476166.parquet', name='Computer_2024-12-23 19:41:03.476166.parquet', size=7366, modificationTime=1734982864000),
#  FileInfo(path='dbfs:/FileStore/landing_zone/Computer/Offline/Computer/Computer_2024-12-23 19:41:14.658863.parquet', name='Computer_2024-12-23 19:41:14.658863.parquet', size=7500, modificationTime=1734982875000),
#  FileInfo(path='dbfs:/FileStore/landing_zone/Computer/Offline/Computer/Computer_2024-12-23 19:41:25.809836.parquet', name='Computer_2024-12-23 19:41:25.809836.parquet', size=7516, modificationTime=1734982887000),
#  FileInfo(path='dbfs:/FileStore/landing_zone/Computer/Offline/Computer/Computer_2024-12-23 19:41:36.927703.parquet', name='Computer_2024-12-23 19:41:36.927703.parquet', size=7590, modificationTime=1734982898000),
#  FileInfo(path='dbfs:/FileStore/landing_zone/Computer/Offline/Computer/Computer_2025-01-12 14:25:08.661946.parquet', name='Computer_2025-01-12 14:25:08.661946.parquet', size=7364, modificationTime=1736691909000),
#  FileInfo(path='dbfs:/FileStore/landing_zone/Computer/Offline/Computer/Computer_2025-01-12 14:25:14.962371.parquet', name='Computer_2025-01-12 14:25:14.962371.parquet', size=7425, modificationTime=1736691916000),
#  FileInfo(path='dbfs:/FileStore/landing_zone/Computer/Offline/Computer/Computer_2025-01-12 14:25:21.362212.parquet', name='Computer_2025-01-12 14:25:21.362212.parquet', size=7456, modificationTime=1736691922000),
#  FileInfo(path='dbfs:/FileStore/landing_zone/Computer/Offline/Computer/Computer_2025-01-12 14:25:27.711497.parquet', name='Computer_2025-01-12 14:25:27.711497.parquet', size=7450, modificationTime=1736691928000),
#  FileInfo(path='dbfs:/FileStore/landing_zone/Computer/Offline/Computer/Computer_2025-01-12 14:25:34.075245.parquet', name='Computer_2025-01-12 14:25:34.075245.parquet', size=7605, modificationTime=1736691935000),
#  FileInfo(path='dbfs:/FileStore/landing_zone/Computer/Offline/Computer/Computer_2025-01-12 14:25:40.390747.parquet', name='Computer_2025-01-12 14:25:40.390747.parquet', size=7446, modificationTime=1736691941000),
#  FileInfo(path='dbfs:/FileStore/landing_zone/Computer/Offline/Computer/Computer_2025-01-12 14:25:46.702171.parquet', name='Computer_2025-01-12 14:25:46.702171.parquet', size=7478, modificationTime=1736691947000),
#  FileInfo(path='dbfs:/FileStore/landing_zone/Computer/Offline/Computer/Computer_2025-01-12 14:25:52.967827.parquet', name='Computer_2025-01-12 14:25:52.967827.parquet', size=7735, modificationTime=1736691954000),
#  FileInfo(path='dbfs:/FileStore/landing_zone/Computer/Offline/Computer/Computer_2025-01-12 14:25:59.209700.parquet', name='Computer_2025-01-12 14:25:59.209700.parquet', size=7643, modificationTime=1736691960000),
#  FileInfo(path='dbfs:/FileStore/landing_zone/Computer/Offline/Computer/Computer_2025-01-12 14:26:05.717670.parquet', name='Computer_2025-01-12 14:26:05.717670.parquet', size=7506, modificationTime=1736691966000),
#  FileInfo(path='dbfs:/FileStore/landing_zone/Computer/Offline/Computer/Computer_2025-01-12 14:26:12.103464.parquet', name='Computer_2025-01-12 14:26:12.103464.parquet', size=7550, modificationTime=1736691973000)]

# %%
#input
origin = 'dbfs:/FileStore/landing_zone/Computer/Offline/Computer'

#output
target_table = "spark_catalog.bronze.computer_offline"
target_path = 'dbfs:/FileStore/bronze/Computer/Offline/Computer'
checkpoint = 'dbfs:/FileStore/bronze/Computer/Offline/Computer_ckpt'
schema = 'dbfs:/FileStore/bronze/Computer/Offline/Computer_schema'
source = 'Computer Offline'

# %%
#Reading new microbatchs for streaming
streamingDF = (spark.readStream.format('cloudFiles') #databricks Auto Loader
    .option('cloudFiles.Format', 'parquet') #specifies we're reading parquet files
    .option('cloudFiles.inferColumnTypes', 'true')   #tells spark to automatically detect data types
    .option('cloudFiles.schemaLocation', schema) #where to store schema
    .option('cloudFiles.schemaEvolutionMode', 'addNewColumns')  #used to handle changes in data structure
    .load(origin)
        #metadata column for tracking
        .withColumn('tracking_source', input_file_name())
        #more metadata
        .withColumn('source', lit(source))
        #file's landing zone ingestion time
        .withColumn('ingestion_date_time', col('_metadata.file_modification_time'))
        #extra column for future flags, if necessary
        .withColumn('status', lit(True)))

# %%
#streamingDF.createOrReplaceTempView("streamingTable")

# %%
# %sql
-- select * from streamingTable

# %%
#Writing data stream into the bronze layer

query = (streamingDF
         .writeStream
         .queryName ("spark_catalog.bronze.computer_offline") #query name
         .format("delta") #delta lake format for ACID, versioning
         .outputMode("append") #( append, complete, update)
         .option("checkpointLocation", checkpoint)
         .option("path", target_path)
         .trigger(availableNow=True) #batch-lie processing, process and finishes
         #.trigger(continuous='1 second') #checking for new data every 1 sec, lower latency but higher resource usage
         #.trigger(processingTime='2 seconds')
         .table(target_table)
         )

#query.awaitTermination()

# %%
# %sql

select * from bronze.computer_offline
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Name</th><th>Address</th><th>IP</th><th>Connection_Time</th><th>Device</th><th>Speed_Connection</th><th>Connection_Status</th><th>_rescued_data</th><th>tracking_source</th><th>source</th><th>ingestion_date_time</th><th>status</th></tr></thead><tbody><tr><td>Tina Adams</td><td>000 Owen Cliffs
# New Samanthashire, AR 49677</td><td>172.29.183.180</td><td>2024-12-23T19:38:20.421086Z</td><td>Computer</td><td>500</td><td>Offline</td><td>null</td><td>dbfs:/FileStore/landing_zone/Computer/Offline/Computer/Computer_2024-12-23%2019:38:21.211050.parquet</td><td>Computer Offline</td><td>2024-12-23T19:38:22Z</td><td>true</td></tr><tr><td>Laura Moore</td><td>51708 Juarez Bridge Suite 450
# New Jennifer, ID 43475</td><td>192.168.18.90</td><td>2024-12-23T19:38:20.421326Z</td><td>Computer</td><td>1000</td><td>Offline</td><td>null</td><td>dbfs:/FileStore/landing_zone/Computer/Offline/Computer/Computer_2024-12-23%2019:38:21.211050.parquet</td><td>Computer Offline</td><td>2024-12-23T19:38:22Z</td><td>true</td></tr><tr><td>Robert Phillips</td><td>19446 Amy Underpass
# Angelaburgh, OK 31321</td><td>10.232.172.205</td><td>2024-12-23T19:38:20.422071Z</td><td>Computer</td><td>1</td><td>Offline</td><td>null</td><td>dbfs:/FileStore/landing_zone/Computer/Offline/Computer/Computer_2024-12-23%2019:38:21.211050.parquet</td><td>Computer Offline</td><td>2024-12-23T19:38:22Z</td><td>true</td></tr><tr><td>David Robinson</td><td>14141 Hannah Landing
# Mccartystad, WY 63893</td><td>192.168.28.208</td><td>2024-12-23T19:38:20.422294Z</td><td>Computer</td><td>10</td><td>Offline</td><td>null</td><td>dbfs:/FileStore/landing_zone/Computer/Offline/Computer/Computer_2024-12-23%2019:38:21.211050.parquet</td><td>Computer Offline</td><td>2024-12-23T19:38:22Z</td><td>true</td></tr><tr><td>